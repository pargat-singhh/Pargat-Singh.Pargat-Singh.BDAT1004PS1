# %% [markdown]
# Question 1
#
# 5            Integer(Whole number)
#
# 5.0          Floating point number
#
# 5 > 1        Boolean
#
# '5'          Character
#
# 5 * 2        Integer(Whole number)
#
# '5' * 2      Character
#
# '5' + '2'    Character
#
# 5 / 2        Floating point number
#
# 5 % 2        Integer(Whole number)
#
# {5,2,1}      Arrays
#
# 5 == 3       Boolean
#
# Pi (number)  Floating point number

# %%
//Question 2  (I have solved this question in jupyter notebook syntax)
Console.WriteLine("Answer 2");
Console.Write("\n"); 
    


    
//Part a
string word = "Supercalifragilisticexpialidocious";
        Console.WriteLine("2a. There are {0} letters in {1} " , word.Length,word);




Console.Write("\n");





//Part b
String main = "Supercalifragilisticexpialidocious";
String sub = "ice";
            if (main.Contains(sub))
            {
                Console.WriteLine("2b. Yes, {0} contains ice as a substring", main);
            }
            else
            {
                Console.WriteLine("2b. No, {0} does not contain ice as a substring",main);
            }




Console.Write("\n");




//Part c

String word1 = "Supercalifragilisticexpialidocious", word2 = "Honorificabilitudinitatibus", word3 = "Bababadalgharaghtakamminarronnkonn";
               
                   int one = word1.Length, two = word2.Length, three = word3.Length;
                   if (one>two)
                    {
                        if (one==three)
                        {
                            Console.WriteLine( "2c. {0},{1} -Both words are equal in length as well as longest", word1,word3);
                        }
                        else if (one>three)
                        {
                            Console.WriteLine( "2c. {0} is the longest", word1);  
                        }
                        else if (one<three)
                        {
                               Console.WriteLine("2c. {0} is the longest", word3);
                        }
                       
                     }
                    else
                    {
                        if (two==three)
                        {
                            Console.WriteLine( "2c. {0},{1} -Both words are equal in length as well as longest", word2,word3);
                        }
                        
                        else if (two>three)
                        {
                              Console.WriteLine("2c. {0} is the longest", word2);
                        }
                        else if (two<three)
                       {
                               Console.WriteLine("2c. {0} is the longest", word3);
                       }
                       
                     }
               


Console.Write("\n");
       


//Part d
var composers = new SortedSet<string>();
           composers.Add("Berlioz"); 
           composers.Add("Borodin");
           composers.Add("Brian");
           composers.Add("Bartok"); 
           composers.Add("Bellini");
           composers.Add("Buxtehude");
           composers.Add("Bernstein");

           Console.WriteLine("2d. Composer that comes first in the dictionary is: {0}",composers.First());
# Out:
#   Input In [1]
#     //Question 2  (I have solved this question in jupyter notebook syntax)
#     ^
# SyntaxError: invalid syntax

# %%
//Question 3

using System;
public class TriangleArea
{
    public static void Main()
    {
        double a,b,c,s,AreaOfTriangle;
        Console.WriteLine("Enter length of side a:");
        a = Convert.ToDouble(Console.ReadLine());
        Console.WriteLine("Enter length of side b:");
        b = Convert.ToDouble(Console.ReadLine());
        Console.WriteLine("Enter length of side c:");
        c = Convert.ToDouble(Console.ReadLine());
        s = (a+b+c) / 2;
        AreaOfTriangle = Math.Sqrt(s * (s - a) * (s - b) * (s - c));
        Console.WriteLine("triangleArea({0},{1},{2})",a,b,c);
        Console.WriteLine(AreaOfTriangle);
        Console.ReadKey();
    }
}

# %%
//Question 4
using System;
public class EvenOdd
{
    public static void Main()
    {
        int[] main = new int[10];
        int[] even = new int[10];
        int[] odd = new int[10];
        int i, j = 0, k = 0, n;

        Console.Write("Input the number of elements to be stored in the array :");
        n = Convert.ToInt32(Console.ReadLine());

        Console.Write("Input {0} elements in the array :\n", n);
        for (i = 0; i < n; i++)
        {
            Console.Write("element - {0} : ", i);
            main[i] = Convert.ToInt32(Console.ReadLine());
        }

        for (i = 0; i < n; i++)
        {
            if (main[i] % 2 == 0)
            {
                even[j] = main[i];
                j++;
            }
            else
            {
                odd[k] = main[i];
                k++;
            }
        }

        Console.Write("\nThe Even elements are : \n");
        for (i = 0; i < j; i++)
        {
            Console.Write("{0} ", even[i]);
        }

        Console.Write("\nThe Odd elements are :\n");
        for (i = 0; i < k; i++)
        {
            Console.Write("{0} ", odd[i]);
        }
        Console.Write("\n\n");
    }
}



//References:
// C# - Separate odd and even integers in separate arrays. (2022, August 19). W3resource. 
// Retrieved October 14, 2022, 
// from https://www.w3resource.com/csharp-exercises/array/csharp-array-exercise-10.php

# %%
//Question 5

//Part a

using System;

class GFG
{
    static bool inside(int x1, int y1, int x2, int y2, int x, int y)
    {
        if (x > x1 && x < x2 && y > y1 && y < y2)
            return true;
        else
            return false;
    }

    public static void Main()
    {

        // Lower-left and upper-right
        // corners of rectangle
        int x1 = 0, y1 = 0,
            x2 = 2, y2 = 3;

        int x = 1, y = 1;   //When value of x and y is changed to -1 and -1 for second case and we get a "False" result
       
        Console.WriteLine("inside({0},{1},{2},{3},{4},{5})",x,y,x1,y1,x2,y2);

        if (inside(x1, y1, x2, y2, x, y))
            Console.Write("True");
        else
            Console.Write("False");

    }
}

//References:
// GeeksforGeeks. (2022, August 18). Check if a point lies inside a rectangle | Set-2. 
//Retrieved October 14, 2022, 
//from https://www.geeksforgeeks.org/check-if-a-point-lies-on-or-inside-a-rectangle-set-2/

# %%
//Question 5

//Part b

using System;

class GFG
{

    static bool inside(double x1, double y1, double x2,
                          double y2, double x, double y)
    {
        if (x > x1 && x < x2 &&
            y > y1 && y < y2)
            return true;
        else
            return false;
    }

    public static void Main()
    {

        // lower-left and upper-right
        // corners of rectangle
        double x1 = 0.3, y1 = 0.5, 
               x2 = 1.1, y2 = 0.7;     //Change value of x1,y1,x2 and y2 for second case and it gives a "True" result

        double x = 1, y = 1;

        Console.WriteLine("inside({0},{1},{2},{3},{4},{5})", x,y,x1,y1,x2,y2);

        if (inside(x,y,x1,y1,x2,y2))
            Console.Write("True, point lies inside");
        else
            Console.Write("False, point does not lie inside");
    }
}

# %%
#Question 6
# Out:
#   Input In [58]
#
#     ^
# IndentationError: expected an indented block

# %%
#Question 7
def bloodcount(bloodtype):
    with open('C:/Users/pargat/OneDrive/Desktop/bloodtype1.txt') as bloodtype:

# %%
#Question 8

def curconv(crncy,amount):
    with open('C:/Users/pargat/OneDrive/Desktop/currencies.txt') as currencies:
        for num, line in enumerate(currencies, 1):
            if crncy in line:
                value=list(line.split())
                print(float(amount)*float(value[1]))
crncy = input("Enter required currency unit:")
amount = input("Enter the amount of currency:")

curconv(crncy,amount)
# Out:
# Enter required currency unit:EUR
# Enter the amount of currency:100
# 122.96544

# %% [markdown]
# Question 9
#
# 1. NumberFormatException
#
# 2. ArrayIndexOutOfBoundsException
#
# 3. ArithmeticException
#
# 4. Compile time error
#
# 5. FileNotFoundException

# %%
#Question 10
